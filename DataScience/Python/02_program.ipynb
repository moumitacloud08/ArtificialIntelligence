# %%
d={'key1':'value','key2':123}

# %%
d['key1']
# Out:
# 'value'

# %%
d ={'k1':[1,2,3]}

# %%
d['k1']
# Out:
# [1, 2, 3]

# %%
my_list = d['k1']

# %%
my_list[0]
# Out:
# 1

# %%
d['k1'][0]
# Out:
# 1

# %%
d={'k1':{'innerkey':[1,2,3]}}

# %%
d['k1']
# Out:
# {'innerkey': [1, 2, 3]}

# %%
t=(1,2,3)

# %%
t[0]
# Out:
# 1

# %%
my_list = [1,2,3]

# %%
my_list[0]
# Out:
# 1

# %%
my_list
# Out:
# [1, 2, 3]

# %%
my_list[0] = 'NEW'

# %%
my_list
# Out:
# ['NEW', 2, 3]
